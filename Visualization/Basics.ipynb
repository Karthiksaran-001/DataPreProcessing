# %% [markdown]
# # Visualization
# - visualization is one of the main part of DataScience & Analysis
# - It helps to Find the Trend

# %% [markdown]
# ## Package in Python For Visualization :
# 1. Matplotlib
# 2. Seaborn
# 3. plotily

# %%
## Base Package 
import pandas as pd
import numpy as np
## Visualization Lib 
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns

# %%
## create a Table 
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2021-07-24',periods=1000),columns=["Data"])
df
# Out:
#                 Data
# 2021-07-24  0.588131
# 2021-07-25  0.897714
# 2021-07-26  0.891531
# 2021-07-27  0.815837
# 2021-07-28  0.035890
# ...              ...
# 2024-04-14  0.992189
# 2024-04-15  0.756037
# 2024-04-16  0.299186
# 2024-04-17  0.261712
# 2024-04-18  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.Data.cumsum()
# Out:
# 2021-07-24      0.588131
# 2021-07-25      1.485845
# 2021-07-26      2.377375
# 2021-07-27      3.193213
# 2021-07-28      3.229102
#                  ...
# 2024-04-14    495.812936
# 2024-04-15    496.568973
# 2024-04-16    496.868159
# 2024-04-17    497.129872
# 2024-04-18    498.098851
# Freq: D, Name: Data, Length: 1000, dtype: float64

# %%
## Cumsum do some operation of our data so the value ranges upto 500
df.Data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                 Data
# 2021-07-24  0.588131
# 2021-07-25  0.897714
# 2021-07-26  0.891531
# 2021-07-27  0.815837
# 2021-07-28  0.035890
# ...              ...
# 2024-04-14  0.992189
# 2024-04-15  0.756037
# 2024-04-16  0.299186
# 2024-04-17  0.261712
# 2024-04-18  0.968979
#
# [1000 rows x 1 columns]

# %%
df["Cum Data"] = df.Data.cumsum()

# %%
df["Cube Of Data"] = df.Data.apply(lambda x : x**3)

# %%
df
# Out:
#                 Data    Cum Data  Cube Of Data
# 2021-07-24  0.588131    0.588131      0.203433
# 2021-07-25  0.897714    1.485845      0.723458
# 2021-07-26  0.891531    2.377375      0.708613
# 2021-07-27  0.815837    3.193213      0.543014
# 2021-07-28  0.035890    3.229102      0.000046
# ...              ...         ...           ...
# 2024-04-14  0.992189  495.812936      0.976749
# 2024-04-15  0.756037  496.568973      0.432145
# 2024-04-16  0.299186  496.868159      0.026781
# 2024-04-17  0.261712  497.129872      0.017926
# 2024-04-18  0.968979  498.098851      0.909794
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize = (10,10)) ## Data is not see becozz the data is almost to zero
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Seaborn

# %% [markdown]
# In Seaborn There are Build in Dataset Available

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
basic_plot = iris.plot(figsize =(7,7),title = "Irish DataSet")
basic_plot.set_xlabel("My X Values ")
basic_plot.set_ylabel("My Y Values ")

plt.show()

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Plot This in Different Ways

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris.iloc[0][:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %% [markdown]
# ## Bar Graph

# %%
iris.iloc[0][:4].plot(kind='bar',title = "Sertosa")
# Out:
# <AxesSubplot:title={'center':'Sertosa'}>

# %%
## Load Titanic 
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
np.random.seed(23)
ran = pd.DataFrame(np.random.rand(10,4) , columns =["A","B","C","D"] )
ran
# Out:
#           A         B         C         D
# 0  0.517298  0.946963  0.765460  0.282396
# 1  0.221045  0.686222  0.167139  0.392442
# 2  0.618052  0.411930  0.002465  0.884032
# 3  0.884948  0.300410  0.589582  0.978427
# 4  0.845094  0.065075  0.294744  0.287934
# 5  0.822466  0.626183  0.110478  0.000529
# 6  0.942166  0.141501  0.421597  0.346489
# 7  0.869785  0.428602  0.828751  0.717852
# 8  0.119227  0.596384  0.129756  0.077534
# 9  0.831205  0.464386  0.162012  0.547975

# %%
ran.plot(kind = "bar")
plt.show()

# %%
## If u bar graph on Horizontal 
ran.plot(kind="barh",figsize=(7,7))
plt.show()

# %% [markdown]
# ## Histogram
# - In Histogram Your x represent the Range
# - Y Axis Represent the Frequency

# %%
iris.plot(kind="hist")
plt.show()
## This is Overlapping

# %%
## See the overlapping
## based on the bins the bar size reduce 
iris.plot(kind="hist" , stacked = True , bins=20,figsize=(8,8),title="Overlapping")
# Out:
# <AxesSubplot:title={'center':'Overlapping'}, ylabel='Frequency'>

# %%
## same with horizontal
iris.plot(kind="hist" , stacked = True , bins=20,figsize=(8,8),title="Overlapping",orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'Overlapping'}, xlabel='Frequency'>

# %%
iris.describe() ## now we see sepal_width is between 2 to 4
## Sepal width between 2 to 3 there is 100 data
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.sepal_width.plot(kind = 'hist',title = "Seoal Width") ## it is between 2 to 4.4
## here 2.0 to 2.25  5 occurance 
## 2.25 to 2.5 7 

## here we see it is  normally distributed(GaussianDistribution)
# Out:
# <AxesSubplot:title={'center':'Seoal Width'}, ylabel='Frequency'>

# %%
iris.petal_width.plot(kind = 'hist',title = "Petal Width")
## here we see it is not Normally Distribution
# Out:
# <AxesSubplot:title={'center':'Petal Width'}, ylabel='Frequency'>

# %%
### Need Seperate Histogram
iris.hist(figsize = (10,10) ,color = 'red' , alpha =.9) ## Alpha is jus color thickness
plt.show()

# %%
iris.hist(figsize = (10,10) ,color = 'red' , alpha =.3) ## Alpha is jus color thickness
plt.show()

# %% [markdown]
# ## Scatter Plot
# - In Scatter Plot we gives our x and y axis

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(kind = "scatter" ,x="sepal_length" ,y ="petal_width")
## Now we see The Sepal_length increasing Petal_width also increasing
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
## Giving color Priority based on 3rd data (Petal Length)
iris.plot(kind = "scatter" ,x="sepal_length" ,y ="petal_width" ,c ="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
## Increasing the Size in Scatter Plot
iris.plot(kind = "scatter" ,x="sepal_length" ,y ="petal_width" ,c ="sepal_length",s=180)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
iris.plot.hexbin(x="sepal_length" ,y ="sepal_width",gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Pie Plot
#  - Pie Plot add the total area with 100%

# %%
df
# Out:
#                 Data    Cum Data  Cube Of Data
# 2021-07-24  0.588131    0.588131      0.203433
# 2021-07-25  0.897714    1.485845      0.723458
# 2021-07-26  0.891531    2.377375      0.708613
# 2021-07-27  0.815837    3.193213      0.543014
# 2021-07-28  0.035890    3.229102      0.000046
# ...              ...         ...           ...
# 2024-04-14  0.992189  495.812936      0.976749
# 2024-04-15  0.756037  496.568973      0.432145
# 2024-04-16  0.299186  496.868159      0.026781
# 2024-04-17  0.261712  497.129872      0.017926
# 2024-04-18  0.968979  498.098851      0.909794
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]
d
# Out:
# Data            0.588131
# Cum Data        0.588131
# Cube Of Data    0.203433
# Name: 2021-07-24 00:00:00, dtype: float64

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-24 00:00:00'>

# %%
(0.588131 + 0.588131 +0.203433)
# Out:
# 1.379695

# %%
0.588131 / 1.379695  *100 ## 42% are data & 42% are CumData
# Out:
# 42.62760972533785

# %%
0.203433 / 1.379695 *100 ##  & 16% are Cube data
# Out:
# 14.744780549324307

# %%
42.62760972533785 + 42.62760972533785 + 14.744780549324307 ## Total 100
# Out:
# 100.0

# %%
trans = iris.head(3).T
trans
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
trans.iloc[:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
trans.iloc[:4].plot.pie(subplots =True , figsize=(20,20) ,fontsize=20,autopct = '%.2f')
## it takes column wise so it gives three piechart 0,1,2
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# ## Gives All the Data Using Pandas Plot
# - All to All relationship
# - Helps to see correlations
# - similar like a seaborn pairplot

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(iris , figsize=(10,10)) 
plt.show()

# %%
## Same using Seaborn pairplot with output data
sns.pairplot(iris ,diag_kind="kde",hue="species")

# %%
## If You want To Disstribution we use "KDE"
pd.plotting.scatter_matrix(iris,figsize = (10,10),diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df.Data.plot(style='r--',legend=True,label="data")
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                 Data    Cum Data  Cube Of Data
# 2021-07-24  0.588131    0.588131      0.203433
# 2021-07-25  0.897714    1.485845      0.723458
# 2021-07-26  0.891531    2.377375      0.708613
# 2021-07-27  0.815837    3.193213      0.543014
# 2021-07-28  0.035890    3.229102      0.000046
# ...              ...         ...           ...
# 2024-04-14  0.992189  495.812936      0.976749
# 2024-04-15  0.756037  496.568973      0.432145
# 2024-04-16  0.299186  496.868159      0.026781
# 2024-04-17  0.261712  497.129872      0.017926
# 2024-04-18  0.968979  498.098851      0.909794
#
# [1000 rows x 3 columns]

# %%
df.Data.plot(legend=True,label="Data",color="green")
df["Cum Data"].plot(legend=True,label="Cum Data",color="orange")
df["Cube Of Data"].plot(legend=True,label=" Cube Data",color="yellow")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Plotily Library

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68724 sha256=8eaf616408065b851e3666491952562b26776123af5cfe1473b1f33f93319769
#   Stored in directory: c:\users\karthik\appdata\local\pip\cache\wheels\e1\27\13\3fe67fa7ea7be444b831d117220b3b586b872c9acd4df480d0
# Successfully built cufflinks
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf ## cufflinks is a connection for plotly

# %%
py.__version__
# Out:
# '5.1.0'

# %%
## Make Graphs Offline
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
## Similar like plot jus a change iplot insted of plot
iris.iplot()
# Out:
# <div>                            <div id="cc7a5ba7-622e-4ca9-a299-e38070cdc3fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.sex.value_counts().iplot(kind="bar")
# Out:
# <div>                            <div id="971ebadd-40b2-4125-9265-0328eee543de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
## Relationship Between Age And Fare
titanic.iplot(kind="scatter",x="fare",y="age",mode="markers",xTitle="Fare",yTitle="Age")
## from this Graph we say that the Age increase Fare not increases
# Out:
# <div>                            <div id="f08e123f-6634-470d-8a0c-0406b47b6c23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
## change the theme 
cf.set_config_file(theme = "solar")
titanic.iplot(kind="scatter",x="fare",y="age",mode="markers",xTitle="Fare",yTitle="Age")
# Out:
# <div>                            <div id="42a64965-38e0-491b-a644-304172b1f123" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme() ### theme of Cufflinks
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#151516', 'font': {'color': '#D9D9D9'}},
#   'paper_bgcolor': '#151516',
#   'plot_bgcolor': '#151516',
#   'yaxis': {'tickfont': {'color': '#C2C2C2'},
#    'gridcolor': '#434343',
#    'titlefont': {'color': '#D9D9D9'},
#    'zerolinecolor': '#666570',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#C2C2C2'},
#    'gridcolor': '#434343',
#    'titlefont': {'color': '#D9D9D9'},
#    'zerolinecolor': '#666570',
#    'showgrid': True},
#   'titlefont': {'color': '#D9D9D9'}},
#  'annotations': {'fontcolor': '#D9D9D9', 'arrowcolor': '#8C8C8C'}}
