# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py): started
#   Building wheel for PyPDF2 (setup.py): finished with status 'done'
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61085 sha256=36e33b70608ba61be597a769048d8c290594c3d1426ee43742f57693572c775e
#   Stored in directory: c:\users\karthik\appdata\local\pip\cache\wheels\d9\dc\ec\72da68331f30074b9950c1737c23cb8a67484e61498bc9713d
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# !pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.3.0-py3-none-any.whl (12.0 MB)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\karthik\anaconda3\envs\pandas\lib\site-packages (from tabula-py) (1.3.2)
# Collecting distro
#   Using cached distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in c:\users\karthik\anaconda3\envs\pandas\lib\site-packages (from tabula-py) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\karthik\anaconda3\envs\pandas\lib\site-packages (from pandas>=0.25.3->tabula-py) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\karthik\anaconda3\envs\pandas\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\karthik\anaconda3\envs\pandas\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.6.0 tabula-py-2.3.0

# %%
from tabula import read_pdf

# %%
df = read_pdf("RPA.pdf")
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: Dec 17, 2021 5:32:47 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Dec 17, 2021 5:32:47 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Dec 17, 2021 5:32:47 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 372 fonts
# []

# %%
import PyPDF2

# %%
file = open("Sample.pdf" , "rb")

# %%
reader = PyPDF2.PdfFileReader(file)
page =  reader.getPage(0)

# %%
print(page.extractText())
# Out:
# 33. PHYSICIAN'S, SUPPLIER'S BILLING NAME, ADDRESS, ZIP CODE &PHONE #25. FEDERAL TAX I.D. NUMBERb. EMPLOYER'S NAME OR SCHOOL NAME23. PRIOR AUTHORIZATION NUMBER20. OUTSIDE LAB?22. MEDICAID RESUBMISSION21. DIAGNOSIS OR NATURE OF ILLNESS OR INJURY. (RELATE ITEMS 1,2,3 OR 4 TO ITEM 24E BY LINE)(SSN or ID)(ID)STATE(VA File #)c. INSURANCE PLAN NAME OR PROGRAM NAMEc. EMPLOYER'S NAME OR SCHOOL NAMEd. INSURANCE PLAN NAME OR PROGRAM NAMEREAD BACK OF FORM BEFORE COMPLETING & SIGNING THIS FORM.13.INSURED'S OR AUTHORIZED PERSON'S SIGNATURE  I authorize paymentof medical benefits to the undersigned physician or supplier for servicesdescribed below.(Explain Unusual Circumstanced)17a. I.D. NUMBER OF REFERRING PHYSICIAN$ CHARGES19. RESERVED FOR LOCAL USENOYESEFGHIJK30. BALANCE DUE29. AMOUNT PAID28. TOTAL CHARGEDCBTypeofServicePlaceofService24.                 AILLNESS (First symptom) ORINJURY (Accident) ORPREGNANCY (LMP)APPROVED OMB-0938-0008HEALTH INSURANCE CLAIM FORM1. MEDICAREMEDICAIDCHAMPUSCHAMPVAGROUPHEALTH PLANFECA BLKLUNGOTHER(Medicare#)(Medicaid #)(Sponsor's SSN)(SSN)1a. INSURED'S I.D. NUMBER(FOR PROGRAM IN ITEM 1)2. PATIENT'S NAME (Last Name, First Name, Middle Initial)3. PATIENT'S BIRTH DATESEXFMMMDDYY4. INSURED'S NAME (Last Name, First Name, Middle Initial)7. INSURED'S ADDRESS (No., Street)5. PATIENT'S ADDRESS (No., Street)CITYCITYZIP CODEZIP CODESTATETELEPHONE (Include Area Code)TELEPHONE (Include Area Code)(        )(        )9. OTHER INSURED'S NAME (Last Name, First Name, Middle Initial)11. INSURED'S POLICY GROUP OR FECA NUMBER6. PATIENT RELATIONSHIP TO INSUREDSelfChildOtherSpouse8. PATIENT STATUS10. IS PATIENT'S CONDITION RELATED TO:a. EMPLOYMENT? (CURRENT OR PREVIOUS)b. AUTO ACCIDENT?c. OTHER ACCIDENT?PLACE (State)SingleMarriedOtherEmployedFull-TimeStudentPart-TimeStudentYESNOYESNOYESNO|______|10d. RESERVED FOR LOCAL USEa. OTHER INSURED'S POLICY OR GROUP NUMBERb. OTHER INSURED'S DATE OF BIRTHMMDDYYSEXFMa. INSURED'S DATE OF BIRTHMMDDYYMSEXFd. IS THERE ANOTHER HEALTH BENEFIT PLAN?YESNOreturn to and complete item 9 a-d.If yes,12.PATIENT'S OR AUTHORIZED PERSON'S SIGNATURE  I authorize the release of any medical or other information necessary toprocess this claim. I also request payment of government benefits either to myself or to the party who accepts assignment below.SIGNEDDATESIGNED14. DATE OF CURRENT:MMDDYY15. IF PATIENT HAS HAD SAME OR SIMILAR ILLNESS.GIVE FIRST DATEMMDDYYMMDDYYMMDDYY16. DATES PATIENT UNABLE TO WORK IN CURRENT OCCUPATIONFROMTO18. HOSPITALIZATION DATES RELATED TO CURRENT SERVICESFROMMMDDYYTOMMDDYY17. NAME OF REFERRING PHYSICIAN OR OTHER SOURCE1. |_________.______2. |_________.______4. |_________.______CODEORIGINAL REF. NO.31. SIGNATURE OF PHYSICIAN OR SUPPLIERINCLUDING DEGREES OR CREDENTIALS    (I certify thatthe statements on the reverse apply to this bill and aremade a part thereof.)SIGNEDDATEPIN #GRP #DATE(S) OF SERVICEPROCEDURES, SERVICES, OR SUPPLIESCPT/hcpcsMODIFIERSSNEIN26. PATIENT'S ACCOUNT NO.(For govt. claims, see back)YESNO32. NAME AND ADDRESS OF FACILITY WHERE SERVICESWERE RENDERED (If other than home or office)PLEASE PRINT OR TYPE123456PICAPICA(APPROVED BY AMA COUNCIL ON MEDICAL SERVICE 8/88)WHCFA-150032CSNFORM CMS-1500           (12-90)FORM OWCP-1500                FORM RRB-150027. ACCEPT ASSIGNMENT?DIAGNOSISCODE3. |_________.______*** REFERENCE COPY -- NOT FOR FILING ***                               X                  00312661701MCCLOUD BLAKE A               09 25 2003  X       HANYZEWSKI TERRY A54759 WINDING BROOK DR                         XMISHAWAKA                IN                       NILES                  MI46545                                             49120                                        X                                        X                                        X         TRICARE EAST                                                          X      SIGNATURE ON FILE             12/17/2021        SIGNATURE ON FILEWESTON-HAMMANG MD ELIZABETH                                ...

# %%
df = read_pdf("Sample.pdf")
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# [             Unnamed: 0  ...                                             PICA.1
#  0                   NaN  ...                            (FOR PROGRAM IN ITEM 1)
#  1                   NaN  ...                                                NaN
#  2                   NaN  ...  4. INSURED'S NAME (Last Name, First Name, Midd...
#  3                   NaN  ...                                                NaN
#  4                   NaN  ...                                 HANYZEWSKI TERRY A
#  5                   NaN  ...                 7. INSURED'S ADDRESS (No., Street)
#  6                   NaN  ...                                                NaN
#  7                   NaN  ...                                         CITY STATE
#  8                   NaN  ...                                            NILESMI
#  9                   NaN  ...             ZIP CODE TELEPHONE (Include Area Code)
#  10                  NaN  ...                                                 ()
#  11                  NaN  ...          11. INSURED'S POLICY GROUP OR FECA NUMBER
#  12                  NaN  ...                     a. INSURED'S DATE OF BIRTH SEX
#  13                  NaN  ...                                           MM DD YY
#  14                  NaN  ...                                                M F
#  15                  NaN  ...                  b. EMPLOYER'S NAME OR SCHOOL NAME
#  16                  NaN  ...                                                NaN
#  17                  NaN  ...                                                NaN
#  18                  NaN  ...             c. INSURANCE PLAN NAME OR PROGRAM NAME
#  19                  NaN  ...                                       TRICARE EAST
#  20                  NaN  ...           d. IS THERE ANOTHER HEALTH BENEFIT PLAN?
#  21                  NaN  ...  Y ESX NO If yes, return to and complete item 9...
#  22                  NaN  ...  13. INSURED'S OR AUTHORIZED PERSON'S SIGNATURE...
#  23                  NaN  ...  of medical benefits to the undersigned physici...
#  24                  NaN  ...                                   described below.
#  25                  NaN  ...                         SIG N ED SIGNATURE ON FILE
#  26                  NaN  ...  16. DATES PATIENT UNABLE TO WORK IN CURRENT OC...
#  27                  NaN  ...                          FROM MM DD YY TO MM DD YY
#  28                  NaN  ...                                                NaN
#  29                  NaN  ...  18. HOSPITALIZATION DATES RELATED TO CURRENT S...
#  30                  NaN  ...                                  MM DD YY MM DD YY
#  31                  NaN  ...                                            FROM TO
#  32                  NaN  ...                         20. OUTSIDE LAB? $ CHARGES
#  33                  NaN  ...                                          YE S X NO
#  34                  NaN  ...    22. MEDICAID RESUBMISSION ORIGINAL REF. NO.CODE
#  35                  NaN  ...                                                NaN
#  36                  NaN  ...                     23. PRIOR AUTHORIZATION NUMBER
#  37                  NaN  ...                                                NaN
#  38                  NaN  ...                                        F G H I J K
#  39                  NaN  ...                                                NaN
#  40                  NaN  ...                                                NaN
#  41                  NaN  ...                                                NaN
#  42                    1  ...                                                NaN
#  43                  NaN  ...                                           165.00 1
#  44                    2  ...                                                NaN
#  45                  NaN  ...                                            45.00 1
#  46  3 07 19 21 07 19 21  ...                                            35.00 1
#  47  4 07 19 21 07 19 21  ...                                           286.00 1
#  48                    5  ...                                                NaN
#  49                    6  ...                                                NaN
#  50                  NaN  ...   28. TOTAL CHARGE 29. AMOUNT PAID 30. BALANCE DUE
#  51                  NaN  ...                                                NaN
#  52                  NaN  ...                                             531.00
#  53                  NaN  ...  33. PHYSICIAN'S, SUPPLIER'S BILLING NAME, ADDR...
#  54                  NaN  ...                                            PHONE #
#  55                  NaN  ...                          THE SOUTH BEND CLINIC LLP
#  56                  NaN  ...                                                NaN
#  57                  NaN  ...                                  211 N EDDY STREET
#  58                  NaN  ...                                SOUTH BEND IN 46617
#  59                  NaN  ...                                        PIN # GRP #
#
#  [60 rows x 7 columns]]

# %%
import pandas as pd

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#              Unnamed: 0  ...                                             PICA.1
# 0                   NaN  ...                            (FOR PROGRAM IN ITEM 1)
# 1                   NaN  ...                                                NaN
# 2                   NaN  ...  4. INSURED'S NAME (Last Name, First Name, Midd...
# 3                   NaN  ...                                                NaN
# 4                   NaN  ...                                 HANYZEWSKI TERRY A
# 5                   NaN  ...                 7. INSURED'S ADDRESS (No., Street)
# 6                   NaN  ...                                                NaN
# 7                   NaN  ...                                         CITY STATE
# 8                   NaN  ...                                            NILESMI
# 9                   NaN  ...             ZIP CODE TELEPHONE (Include Area Code)
# 10                  NaN  ...                                                 ()
# 11                  NaN  ...          11. INSURED'S POLICY GROUP OR FECA NUMBER
# 12                  NaN  ...                     a. INSURED'S DATE OF BIRTH SEX
# 13                  NaN  ...                                           MM DD YY
# 14                  NaN  ...                                                M F
# 15                  NaN  ...                  b. EMPLOYER'S NAME OR SCHOOL NAME
# 16                  NaN  ...                                                NaN
# 17                  NaN  ...                                                NaN
# 18                  NaN  ...             c. INSURANCE PLAN NAME OR PROGRAM NAME
# 19                  NaN  ...                                       TRICARE EAST
# 20                  NaN  ...           d. IS THERE ANOTHER HEALTH BENEFIT PLAN?
# 21                  NaN  ...  Y ESX NO If yes, return to and complete item 9...
# 22                  NaN  ...  13. INSURED'S OR AUTHORIZED PERSON'S SIGNATURE...
# 23                  NaN  ...  of medical benefits to the undersigned physici...
# 24                  NaN  ...                                   described below.
# 25                  NaN  ...                         SIG N ED SIGNATURE ON FILE
# 26                  NaN  ...  16. DATES PATIENT UNABLE TO WORK IN CURRENT OC...
# 27                  NaN  ...                          FROM MM DD YY TO MM DD YY
# 28                  NaN  ...                                                NaN
# 29                  NaN  ...  18. HOSPITALIZATION DATES RELATED TO CURRENT S...
# 30                  NaN  ...                                  MM DD YY MM DD YY
# 31                  NaN  ...                                            FROM TO
# 32                  NaN  ...                         20. OUTSIDE LAB? $ CHARGES
# 33                  NaN  ...                                          YE S X NO
# 34                  NaN  ...    22. MEDICAID RESUBMISSION ORIGINAL REF. NO.CODE
# 35                  NaN  ...                                                NaN
# 36                  NaN  ...                     23. PRIOR AUTHORIZATION NUMBER
# 37                  NaN  ...                                                NaN
# 38                  NaN  ...                                        F G H I J K
# 39                  NaN  ...                                                NaN
# 40                  NaN  ...                                                NaN
# 41                  NaN  ...                                                NaN
# 42                    1  ...                                                NaN
# 43                  NaN  ...                                           165.00 1
# 44                    2  ...                                                NaN
# 45                  NaN  ...                                            45.00 1
# 46  3 07 19 21 07 19 21  ...                                            35.00 1
# 47  4 07 19 21 07 19 21  ...                                           286.00 1
# 48                    5  ...                                                NaN
# 49                    6  ...                                                NaN
# 50                  NaN  ...   28. TOTAL CHARGE 29. AMOUNT PAID 30. BALANCE DUE
# 51                  NaN  ...                                                NaN
# 52                  NaN  ...                                             531.00
# 53                  NaN  ...  33. PHYSICIAN'S, SUPPLIER'S BILLING NAME, ADDR...
# 54                  NaN  ...                                            PHONE #
# 55                  NaN  ...                          THE SOUTH BEND CLINIC LLP
# 56                  NaN  ...                                                NaN
# 57                  NaN  ...                                  211 N EDDY STREET
# 58                  NaN  ...                                SOUTH BEND IN 46617
# 59                  NaN  ...                                        PIN # GRP #
#
# [60 rows x 7 columns]

# %%
str(df)
# Out:
# "[             Unnamed: 0  ...                                             PICA.1\n0                   NaN  ...                            (FOR PROGRAM IN ITEM 1)\n1                   NaN  ...                                                NaN\n2                   NaN  ...  4. INSURED'S NAME (Last Name, First Name, Midd...\n3                   NaN  ...                                                NaN\n4                   NaN  ...                                 HANYZEWSKI TERRY A\n5                   NaN  ...                 7. INSURED'S ADDRESS (No., Street)\n6                   NaN  ...                                                NaN\n7                   NaN  ...                                         CITY STATE\n8                   NaN  ...                                            NILESMI\n9                   NaN  ...             ZIP CODE TELEPHONE (Include Area Code)\n10                  NaN  ...                                                 ()\n11                  NaN  ...          11. INSURED'S POLICY GROUP OR FECA NUMBER\n12                  NaN  ...                     a. INSURED'S DATE OF BIRTH SEX\n13                  NaN  ...                                           MM DD YY\n14                  NaN  ...                                                M F\n15                  NaN  ...                  b. EMPLOYER'S NAME OR SCHOOL NAME\n16                  NaN  ...                                                NaN\n17                  NaN  ...                                                NaN\n18                  NaN  ...             c. INSURANCE PLAN NAME OR PROGRAM NAME\n19                  NaN  ...                                       TRICARE EAST\n20                  NaN  ...           d. IS THERE ANOTHER HEALTH BENEFIT PLAN?\n21                  NaN  ...  Y ESX NO If yes, return to and complete item 9...\n22                  NaN  ...  13. INSURED'S OR AUTHORIZED PERSON'S SIGNATURE...\n23                  NaN  ...  of medical benefits to the undersigned physici...\n24                  NaN  ...                                   described below.\n25                  NaN  ...                         SIG N ED SIGNATURE ON FILE\n26                  NaN  ...  16. DATES PATIENT UNABLE TO WORK IN CURRENT OC...\n27                  NaN  ...                          FROM MM DD YY TO MM DD YY\n28                  NaN  ...                                                NaN\n29                  NaN  ...  18. HOSPITALIZATION DATES RELATED TO CURRENT S...\n30                  NaN  ...                                  MM DD YY MM DD YY\n31                  NaN  ...                                            FROM TO\n32                  NaN  ...                         20. OUTSIDE LAB? $ CHARGES\n33                  NaN  ...                                          YE S X NO\n34                  NaN  ...    22. MEDICAID RESUBMISSION ORIGINAL REF. NO.CODE\n35                  NaN  ...                                                NaN\n36                  NaN  ...                     23. PRIOR AUTHORIZATION NUMBER\n37                  NaN  ...                                                NaN\n38                  NaN  ...                                        F G H I J K\n39                  NaN  ...                                                NaN\n40                  NaN  ...                                                NaN\n41                  NaN  ...                                                NaN\n42                    1  ...                                                NaN\n43                  NaN  ...                                           165.00 1\n44                    2  ...                                                NaN\n45                  NaN  ...                                            45.00 1\n46  3 07 19 21 07 19 21  ...                                            35.00 1\n47  4 07 19 21 07 19 21  ...                                           286.00 1\n48                    5  ...  ...

# %% [markdown]
# ## TXT

# %%
f = open("PDF.txt" ,'r+')
f
# Out:
# <_io.TextIOWrapper name='PDF.txt' mode='r+' encoding='cp1252'>

# %%
for i , j in enumerate(f):
    if(i >= 53 and i<=57):
        print(f"Line No :  {i} ;  The Data Are : {j}")
# Out:
# Line No :  53 ;  The Data Are : 1 07 19 21 07 19 21       99214 25           2       165.00 1
#
# Line No :  54 ;  The Data Are : 2 07 19 21 07 19 21       90471              4        45.00 1
#
# Line No :  55 ;  The Data Are : 3 07 19 21 07 19 21       99173 59           3        35.00 1
#
# Line No :  56 ;  The Data Are : 4 07 19 21 07 19 21       90620              4       286.00 1
#
# Line No :  57 ;  The Data Are : 5

# %%
f = open("PDF.txt" ,'r+')
f
for i , j  in enumerate(f):
   print(i , j)
# Out:
# 0 *** REFERENCE COPY -- NOT FOR FILING *** APPROVED OMB-0938-0008
#
# 1
#
# 2 PICA HEALTH INSURANCE CLAIM FORM PICA
#
# 3 1. MEDICARE MEDICAID CHAMPUS CHAMPVA GROUP FECA BLK OTHER 1a. INSURED'S I.D. NUMBER (FOR PROGRAM IN ITEM 1)
#
# 4 X                  00312661701HEALTH PLAN LUNG (ID)
#
# 5 (Medicare#) (Medicaid #) (Sponsor's SSN) (VA File #) (SSN or ID) (SSN)
#
# 6 2. PATIENT'S NAME (Last Name, First Name, Middle Initial) 3. PATIENT'S BIRTH DATE SEX 4. INSURED'S NAME (Last Name, First Name, Middle Initial)
#
# 7 MM DD YY
#
# 8 MCCLOUD BLAKE A               09 25 2003  X       HANYZEWSKI TERRY AM F
#
# 9 5. PATIENT'S ADDRESS (No., Street) 6. PATIENT RELATIONSHIP TO INSURED 7. INSURED'S ADDRESS (No., Street)
#
# 10 54759 WINDING BROOK DR                         X
#
# 11 Self Spouse Child Other
#
# 12 CITY STATE 8. PATIENT STATUS CITY STATE
#
# 13 MISHAWAKA                IN                       NILES                  MISingle Married Other
#
# 14 ZIP CODE TELEPHONE (Include Area Code) ZIP CODE TELEPHONE (Include Area Code)
#
# 15 46545                                             49120(        ) Employed Full-Time Part-Time (        )
#
# 16 Student Student
#
# 17 9. OTHER INSURED'S NAME (Last Name, First Name, Middle Initial) 10. IS PATIENT'S CONDITION RELATED TO: 11. INSURED'S POLICY GROUP OR FECA NUMBER
#
# 18
#
# 19 a. OTHER INSURED'S POLICY OR GROUP NUMBER a. EMPLOYMENT? (CURRENT OR PREVIOUS) a. INSURED'S DATE OF BIRTH SEX
#
# 20 XYES NO PLACE (State) MM DD YY M F
#
# 21 b. OTHER INSURED'S DATE OF BIRTH SEX b. AUTO ACCIDENT? b. EMPLOYER'S NAME OR SCHOOL NAME
#
# 22 MM DD YY
#
# 23 XM F YES NO |______|
#
# 24 c. EMPLOYER'S NAME OR SCHOOL NAME c. OTHER ACCIDENT? c. INSURANCE PLAN NAME OR PROGRAM NAME
#
# 25 X         TRICARE EASTYES NO
#
# 26 d. INSURANCE PLAN NAME OR PROGRAM NAME 10d. RESERVED FOR LOCAL USE d. IS THERE ANOTHER HEALTH BENEFIT PLAN?
#
# 27 X NO If yes, return to and complete item 9 a-d.
#
# 28 YES
#
# 29 READ BACK OF FORM BEFORE COMPLETING & SIGNING THIS FORM. 13.INSURED'S OR AUTHORIZED PERSON'S SIGNATURE  I authorize payment
#
# 30 12.PATIENT'S OR AUTHORIZED PERSON'S SIGNATURE  I authorize the release of any medical or other information necessary to of medical benefits to the undersigned physician or supplier for services
#
# 31 process this claim. I also request payment of government benefits either to myself or to the party who accepts assignment below. described below.
#
# 32 SIGNATURE ON FILE             12/17/2021        SIGNATURE ON FILE
#
# 33 SIGNED DATE SIGNED
#
# 34 14. DATE OF CURRENT: ILLNESS (First symptom) OR 15. IF PATIENT HAS HAD SAME OR SIMILAR ILLNESS. 16. DATES PATIENT UNABLE TO WORK IN CURRENT OCCUPATION
#
# 35 MM DD YY INJURY (Accident) OR GIVE FIRST DATE MM DD YY FROM MM DD YY TO MM DD YY
#
# 36 PREGNANCY (LMP)
#
# 37 17. NAME OF REFERRING PHYSICIAN OR OTHER SOURCE 17a. I.D. NUMBER OF REFERRING PHYSICIAN 18. HOSPITALIZATION DATES RELATED TO CURRENT SERVICES
#
# 38 WESTON-HAMMANG MD ELIZABETH FROM MM DD YY TO MM DD YY
#
# 39 19. RESERVED FOR LOCAL USE 20. OUTSIDE LAB? $ CHARGES
#
# 40 X NO
#
# 41 YES
#
# 42 21. DIAGNOSIS OR NATURE OF ILLNESS OR INJURY. (RELATE ITEMS 1,2,3 OR 4 TO ITEM 24E BY LINE) 22. MEDICAID RESUBMISSION ORIGINAL REF. NO.
#
# 43 CODE
#
# 44 F33 1                       Z13 5
#
# 45 1. |_________.______ 3. |_________.______
#
# 46 23. PRIOR AUTHORIZATION NUMBER
#
# 47 Z02 5                       Z23
#
# 48 2. |_________.______ 4. |_________.______
#
# 49 24.                 A B C D E F G H I J K
#
# 50 DATE(S) OF SERVICE Place Type PROCEDURES, SERVICES, OR SUPPLIES
#
# 51 of of (Explain Unusual Circumstanced) DIAGNOSIS
#
# 52 Service Service CPT/hcpcs MODIFIER CODE
#
# 53 1 07 19 21 07 19 21       99214 25           2       165.00 1
#
# 54 2 07 19 21 07 19 21       90471              4        45.00 1
#
# 55 3 07 19 21 07 19 21       99173 59           3        35.00 1
#
# 56 4 07 19 21 07 19 21       90620              4       286.00 1
#
# 57 5
#
# 58
#
# 59 6
#
# 60 25. FEDERAL TAX I.D. NUMBER SSN EIN 26. PATIENT'S ACCOUNT NO. 27. ACCEPT ASSIGNMENT? 28. TOTAL CHARGE 29. AMOUNT PAID 30. BALANCE DUE
#
# 61 (For govt. claims, see back)
#
# 62 1073680419        X   SB0022733561   X                531.00
#
# 63 YES NO
#
# 64 31. SIGNATURE OF PHYSICIAN OR SUPPLIER 32. NAME AND ADDRESS OF FACILITY WHERE SERVICES 33. PHYSICIAN'S, SUPPLIER'S BILLING NAME, ADDRESS, ZIP CODE &
#
# 65 INCLUDING DEGREES OR CREDENTIALS    (I certify that WERE RENDERED (If other than home or office) PHONE #
#
# 66 GRANGER FAMILY MEDICINE     THE SOUTH BEND CLINIC LLPthe statements on the reverse apply to this bill and are
#
# 67 made a part thereof.)
#
# 68 WESTON-HAMMANG MD ELIZ52500 FIR ROADABETH A       211 N EDDY STREET
#
# 69 GRANGER IN 46530            SOUTH BEND IN 46617
#
# 70 12/17/21 PIN # GRP #
#
# 71 SIGNED DATE
#
# 72 FORM CMS-1500           (12-90)
#
# 73 (APPROVED BY AMA COUNCIL ON MEDICAL SERVICE 8/88) PLEASE PRINT OR TYPE FORM OWCP-1500                FORM RRB-1500
#
# 74 WHCFA-150032CSN

# %%
f = open("PDF.txt" ,'r+')
f

for i , j  in enumerate(f):
    if(j.startswith("Service")):
        start =i
       
    if(j.startswith("6")):
        end = i
        
    if(i > start and i <= end):
        print(j)
# Out:
# 1 07 19 21 07 19 21       99214 25           2       165.00 1
#
# 2 07 19 21 07 19 21       90471              4        45.00 1
#
# 3 07 19 21 07 19 21       99173 59           3        35.00 1
#
# 4 07 19 21 07 19 21       90620              4       286.00 1
#
# 5
#
#
#
# 6

# %%
    if(j.startswith("Service")):
        start =i
        print(start)
     if(i > start and i < end):
        print(j)
